# %%
print("Hello World")
# Out:
# Hello World

# %%
a = 10
b= 20
c = a + b
print("Sum:", c)
# Out:
# Sum: 30

# %%
a = 5

print(type(a))
# Out:
# <class 'int'>

# %%
arr = [1, 2, 3, 4, 5]
print("Array:", len(arr))
# Out:
# Array: 5

# %%
type(range)

print(type(range))
# Out:
# <class 'type'>

# %%
a = [1,2,34]

a.append(4)

print(a)
# Out:
# [1, 2, 34, 4]

# %%
s =  " is awesome! They say it is the \"best\" programming language."
t = "Python"

print(f"Learning {t + s}")
# Out:
# Learning Python is awesome! They say it is the "best" programming language.

# %%
l = range(2,10)
print(tuple(l))
# Out:
# (2, 3, 4, 5, 6, 7, 8, 9)

# %%
val = "Imvijat0"

print(val.startswith("0"))
# Out:
# False

# %%
val = "print the value"

print(val.capitalize())

print(val[1:2])
# Out:
# Print the value
# r

# %%
var1 = "Hello world, it's a beautiful day"
# print(var1[1:8])

print(var1[-2:-20:-2])
# Out:
# a uiue  '

# %%
m = "Helllo"

print( m if m != "Hello" else "orange")
# Out:
# Helllo

# %%
fruits = ["apple", "banana", "cherry", "kiwi", "mango"]

newlist = [x if x != "banana" else "orange" for x in fruits]

print(newlist)
# Out:
# ['apple', 'orange', 'cherry', 'kiwi', 'mango']

# %%
data = [383,273,473,103,94,58,29,493,392,203]

def sort_key(x):
    return x / 10

data.sort(key=sort_key,reverse=True)

print(data)
# Out:
# [493, 473, 392, 383, 273, 203, 103, 94, 58, 29]

# %%
s = ['spam', 'Spam', 'SPAM!','SPaM']

s.sort()

print(type(s))
s.reverse()

print(s)
# Out:
# <class 'list'>
# ['spam', 'Spam', 'SPaM', 'SPAM!']
